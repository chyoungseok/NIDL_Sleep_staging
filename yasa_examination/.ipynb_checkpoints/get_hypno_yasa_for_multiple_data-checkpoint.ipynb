# %% [markdown]
# # Hypnogram Extraction Using YASA
# ### YASA 모델을 이용하여, prepared subject에 대한 hypnogram을 얻는다

# %%
import each_subject

df_accuracy = each_subject.by_eeg_eog(0)
# Out:
# ['LE004 박규희', 'LE010 신지윤', 'LE011 서영진', 'LE014 황지은', 'LE019 황주민', 'LE020 김세영', 'LE021 이지영', 'LE022 양세희', 'LE023 이해림']
#
# -- Number of prepared subjects: 9
# Now edf: G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE004 박규희\Traces.edf
# Extracting EDF parameters from G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE004 박규희\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11347999  =      0.000 ... 22695.998 secs...
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:30: RuntimeWarning: Channel names are not unique, found duplicates for: {'R-Leg', 'LOC', 'Chin', 'EKG', 'ROC', 'L-Leg', 'SO'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:30: RuntimeWarning: Scaling factor is not defined in following channels:
# Flattening, Pleth Amplitude, Chin-0, Chin-1, L-Leg-0, L-Leg-1, EKG-0, EKG-1, R-Leg-0, R-Leg-1, SO-0, SO-1, LOC-0, LOC-1, ROC-0, ROC-1, A1, C3, C4, A2, O1, O2, IO, F3, F4, Light_BU, Nasal Pressure, Thermistor, Snoring Sensor, Thorax, Abdomen, Gravity X, Gravity Y, Plethysmogram, Pulse, RD-Quality, SpO2, SpO2 BB, Heart Rate_DR, SpO2-Quality_DR, Flow_DR, Snore_DR, Activity_DR, Elevation_DR, Position_DR, Phase_DR, RMI_DR, RR_DR, XSum_DR, Tidal Volume_DR, XFlow_DR
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# -- Available Channels: ['SO-0', 'SO-1', 'C3', 'C4', 'IO']
# ['LE004-Events.txt', 'LE010-Events.txt', 'LE011-Events.txt', 'LE014-Events.txt', 'LE019-Events.txt', 'LE020-Events.txt', 'LE021-Events.txt', 'LE022-Events.txt', 'LE023-Events.txt', 'LE029-Events.txt', 'LE031-Events.txt', 'LGD001-Events.txt', 'LGD008-Events.txt', 'LGD011-Events.txt', 'LGD018-Events.txt', 'PE160114-Events.txt', 'PE170580-Events.txt', 'PE170897-Events.txt', 'PE180662-Events.txt', 'PE180718-Events.txt', 'PE180750-Events.txt', 'PE180778-Events.txt', 'PE180807-Events.txt', 'PE180814-Events.txt', 'PE180820-Events.txt', 'PE180846-Events.txt', 'PE180891-Events.txt', 'PE180923-Events.txt', 'PE181020-Events.txt', 'PE181068-Events.txt', 'PE181189-Events.txt', 'PE181236-Events.txt', 'PE190732-Events.txt', 'PE191128-Events.txt']
#
#  -- Now subject is: LE004-Events.txt
# ['Sleep', 'Stage', 'Time', '[hh:mm:ss]', 'Event', 'Duration[s]']
# ['SLEEP-S0', '00:31:00', 'SLEEP-S0', '30']
# ['SLEEP-S0', '05:52:00', 'SLEEP-S0', '30']
#
# hypno_start: 00:31:00
# hypno_end: 05:52:00
#
# hypno_start: 1860 seconds
# hypno_end: 21120 seconds
# edf_start: 1089 seconds
# -- Original sampling rate: 500.0
# -- Sampling rate after downsampled: 100.0
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 47.50 Hz)
# - Filter length: 1101 samples (11.010 sec)
#
# Shape of single EEG data: (5, 1929000)
#
# ========================================================================
# ========================================================================
# EOG: no_eog, EEG: C3
# <class 'str'> <class 'str'>
# Save as: G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\predicted_hypnogram\LE004.csv
# -- Total prepared hypnograms: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv', 'LE022.csv', 'LE023.csv']
#
# -- Now hypnogram: LE004.csv
# Length of ground_truth: 643
# Length of predicted: 643
# The accuracy is 56.143%
#
# ========================================================================
# ========================================================================
# EOG: no_eog, EEG: C4
# <class 'str'> <class 'str'>
# Save as: G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\predicted_hypnogram\LE004.csv
# -- Total prepared hypnograms: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv', 'LE022.csv', 'LE023.csv']
#
# -- Now hypnogram: LE004.csv
# Length of ground_truth: 643
# Length of predicted: 643
# The accuracy is 56.299%
#
# ========================================================================
# ========================================================================
# EOG: SO-0, EEG: C3
# <class 'str'> <class 'str'>
# Save as: G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\predicted_hypnogram\LE004.csv
# -- Total prepared hypnograms: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv', 'LE022.csv', 'LE023.csv']
#
# -- Now hypnogram: LE004.csv
# Length of ground_truth: 643
# Length of predicted: 643
# The accuracy is 50.078%
#
# ========================================================================
# ========================================================================
# EOG: SO-0, EEG: C4
# <class 'str'> <class 'str'>
# Save as: G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\predicted_hypnogram\LE004.csv
# -- Total prepared hypnograms: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv', 'LE022.csv', 'LE023.csv']
#
# -- Now hypnogram: LE004.csv
# Length of ground_truth: 643
# Length of predicted: 643
# The accuracy is 47.900%
#
# ========================================================================
# ========================================================================
# EOG: SO-1, EEG: C3
# <class 'str'> <class 'str'>
# Save as: G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\predicted_hypnogram\LE004.csv
# -- Total prepared hypnograms: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv', 'LE022.csv', 'LE023.csv']
#
# -- Now hypnogram: LE004.csv
# Length of ground_truth: 643
# Length of predicted: 643
# The accuracy is 45.101%
#
# ========================================================================
# ========================================================================
# EOG: SO-1, EEG: C4
# <class 'str'> <class 'str'>
# Save as: G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\predicted_hypnogram\LE004.csv
# -- Total prepared hypnograms: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv', 'LE022.csv', 'LE023.csv']
#
# -- Now hypnogram: LE004.csv
# Length of ground_truth: 643
# Length of predicted: 643
# The accuracy is 45.412%
#
# ========================================================================
# ========================================================================
# EOG: IO, EEG: C3
# <class 'str'> <class 'str'>
# Save as: G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\predicted_hypnogram\LE004.csv
# -- Total prepared hypnograms: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv', 'LE022.csv', 'LE023.csv']
#
# -- Now hypnogram: LE004.csv
# Length of ground_truth: 643
# Length of predicted: 643
# The accuracy is 46.501%
#
# ========================================================================
# ========================================================================
# EOG: IO, EEG: C4
# <class 'str'> <class 'str'>
# Save as: G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\predicted_hypnogram\LE004.csv
# -- Total prepared hypnograms: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv', 'LE022.csv', 'LE023.csv']
#
# -- Now hypnogram: LE004.csv
# Length of ground_truth: 643
# Length of predicted: 643
# The accuracy is 45.723%

# %%
df_accuracy
# Out:
#            Accuracy [%}
# no_eog_C3     56.143079
# no_eog_C4     56.298600
# SO-0_C3       50.077760
# SO-0_C4       47.900467
# SO-1_C3       45.101089
# SO-1_C4       45.412131
# IO_C3         46.500778
# IO_C4         45.723173
