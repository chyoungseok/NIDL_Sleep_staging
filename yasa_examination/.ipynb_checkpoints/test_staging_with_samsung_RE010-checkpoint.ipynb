# %%
import mne
raw = mne.io.read_raw_edf('D:\\USC\\test_data\\Traces.edf', preload=True)
raw
# Out:
# Extracting EDF parameters from D:\USC\test_data\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\CYS\AppData\Local\Temp\ipykernel_3460\678910173.py:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'LOC', 'ROC'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf('D:\\USC\\test_data\\Traces.edf', preload=True)
# C:\Users\CYS\AppData\Local\Temp\ipykernel_3460\678910173.py:2: RuntimeWarning: Scaling factor is not defined in following channels:
# Flattening, Pleth Amplitude, Chin, L-Leg, EKG, R-Leg, SO, LOC-0, LOC-1, ROC-0, ROC-1, A1, C3, C3-A2, C4, C4-A1, A2, O1, O1-A2, O2, O2-A1, IO, F3, F3-A2, F4, F4-A1, Light_BU, Nasal Pressure, Thermistor, Snoring Sensor, Thorax, Abdomen, Gravity X, Gravity Y, Plethysmogram, Pulse, RD-Quality, SpO2, SpO2 BB, Heart Rate_DR, SpO2-Quality_DR, Flow_DR, Snore_DR, Activity_DR, Elevation_DR, Position_DR, Phase_DR, RMI_DR, RR_DR, XSum_DR, Tidal Volume_DR, XFlow_DR
#   raw = mne.io.read_raw_edf('D:\\USC\\test_data\\Traces.edf', preload=True)
# Reading 0 ... 11184999  =      0.000 ... 22369.998 secs...
# <RawEDF | Traces.edf, 52 x 11185000 (22370.0 s), ~4.33 GB, data loaded>

# %%
print(raw.ch_names)
# Out:
# ['Flattening', 'Pleth Amplitude', 'Chin', 'L-Leg', 'EKG', 'R-Leg', 'SO', 'LOC-0', 'LOC-1', 'ROC-0', 'ROC-1', 'A1', 'C3', 'C3-A2', 'C4', 'C4-A1', 'A2', 'O1', 'O1-A2', 'O2', 'O2-A1', 'IO', 'F3', 'F3-A2', 'F4', 'F4-A1', 'Light_BU', 'Nasal Pressure', 'Thermistor', 'Snoring Sensor', 'Thorax', 'Abdomen', 'Gravity X', 'Gravity Y', 'Plethysmogram', 'Pulse', 'RD-Quality', 'SpO2', 'SpO2 BB', 'Heart Rate_DR', 'SpO2-Quality_DR', 'Flow_DR', 'Snore_DR', 'Activity_DR', 'Elevation_DR', 'Position_DR', 'Phase_DR', 'RMI_DR', 'RR_DR', 'XSum_DR', 'Tidal Volume_DR', 'XFlow_DR']

# %%
# remove the EOG, EMG, and EKG channels
# raw.drop_channels(['ROC-A1', 'LOC-A2', 'EMG1-EMG2', 'EKG-R-EKG-L'])
raw.pick_channels(['C3-A2'])
chan = raw.ch_names
print(chan)
# Out:
# ['C3-A2']

# %%
# Downsampling and filtering
print(raw.info['sfreq'])
# Out:
# 500.0

# %%
raw.resample(100)
sf = raw.info['sfreq']
sf
# Out:
# 100.0

# %%
# 0.3-45 Hz bandpass-filter
raw.filter(0.3, 45)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 47.50 Hz)
# - Filter length: 1101 samples (11.010 sec)
# <RawEDF | Traces.edf, 1 x 2237000 (22370.0 s), ~17.1 MB, data loaded>

# %%
data = raw.get_data() * 1e6
print(data.shape)
# Out:
# (1, 2237000)

# %%
# Hynogram
import pandas as pd
hypno = pd.read_csv("D:\\USC\\test_data\\Traces_hypo.csv", squeeze=True)
hypno
# Out:
# C:\Users\CYS\AppData\Local\Temp\ipykernel_3460\3787308357.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   hypno = pd.read_csv("D:\\USC\\test_data\\Traces_hypo.csv", squeeze=True)
# 0      0
# 1      0
# 2      0
# 3      2
# 4      0
#       ..
# 689    3
# 690    3
# 691    3
# 692    0
# 693    0
# Name: stages, Length: 694, dtype: int64

# %%
import yasa
yasa.plot_hypnogram(hypno);

# %%
# sleep statistics and stage-transition matrix
yasa.sleep_statistics(hypno, sf_hyp=1/30)
# Out:
# {'TIB': 347.0,
#  'SPT': 344.5,
#  'WASO': 12.5,
#  'TST': 332.0,
#  'N1': 74.5,
#  'N2': 14.0,
#  'N3': 216.5,
#  'REM': 27.0,
#  'NREM': 305.0,
#  'SOL': 1.5,
#  'Lat_N1': 77.5,
#  'Lat_N2': 1.5,
#  'Lat_N3': 3.5,
#  'Lat_REM': 4.5,
#  '%N1': 22.43975903614458,
#  '%N2': 4.216867469879518,
#  '%N3': 65.21084337349397,
#  '%REM': 8.132530120481928,
#  '%NREM': 91.86746987951807,
#  'SE': 95.67723342939482,
#  'SME': 96.37155297532657}

# %%
counts, probs = yasa.transition_matrix(hypno)
probs.round(3)
# Out:
# To Stage        0      1      2      3      4
# From Stage
# 0           0.655  0.000  0.310  0.034  0.000
# 1           0.007  0.980  0.007  0.007  0.000
# 2           0.107  0.071  0.179  0.643  0.000
# 3           0.014  0.002  0.028  0.894  0.062
# 4           0.000  0.000  0.019  0.481  0.500

# %%
# Spectral analyses
# Full-night spectrogram plot

# %%
hypno_up = yasa.hypno_upsample_to_data(hypno, sf_hypno=1/30, data=raw)
print(len(hypno_up))
# Out:
# 29-Mar-22 00:24:16 | WARNING | Hypnogram is SHORTER than data by 1550.00 seconds. Padding hypnogram with last value to match data.size.
# 2237000

# %%
chan
# Out:
# ['C3-A2']

# %%
# we select only the C$-A1 EEG channel
yasa.plot_spectrogram(data[chan.index("C3-A2")], sf, hypno_up)

# %%
# automatic sleep staging
sls = yasa.SleepStaging(raw, eeg_name='C3-A2')
hypno_pred = sls.predict()  # Predict the sleep stages
hypno_pred = yasa.hypno_str_to_int(hypno_pred)  # Convert "W" to 0, "N1" to 1, etc
yasa.plot_hypnogram(hypno_pred[-695:-1]);  # Plot
# Out:
# 29-Mar-22 00:25:46 | INFO | Using pre-trained classifier: C:\Users\CYS\Anaconda3\envs\env_yasa\lib\site-packages\yasa\classifiers\clf_eeg_lgb_0.5.0.joblib

# %%
from sklearn.metrics import accuracy_score
print(f"The accuracy is {100 * accuracy_score(hypno, hypno_pred[-695:-1]):.3f}%")
# Out:
# The accuracy is 9.510%
