# %% [markdown]
# # Hypnogram Extraction Using YASA
# ### YASA 모델을 이용하여, prepared subject에 대한 hypnogram을 얻는다

# %%
import each_subject
i = 0

# %%
df_accuracy = each_subject.by_eeg_eog(i)
i += 1
df_accuracy
# Out:
# ['LE004 박규희', 'LE010 신지윤', 'LE011 서영진', 'LE014 황지은', 'LE019 황주민', 'LE020 김세영', 'LE021 이지영', 'LE023 이해림']
#
# -- Number of prepared subjects: 8
# Now edf: G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE004 박규희\Traces.edf
# Extracting EDF parameters from G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE004 박규희\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11347999  =      0.000 ... 22695.998 secs...
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'L-Leg', 'R-Leg', 'Chin', 'EKG', 'LOC', 'SO', 'ROC'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Scaling factor is not defined in following channels:
# ...

# %%
df_accuracy = each_subject.by_eeg_eog(i)
i += 1
df_accuracy
# Out:
# ['LE004 박규희', 'LE010 신지윤', 'LE011 서영진', 'LE014 황지은', 'LE019 황주민', 'LE020 김세영', 'LE021 이지영', 'LE023 이해림']
#
# -- Number of prepared subjects: 8
# Now edf: G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE010 신지윤\Traces.edf
# Extracting EDF parameters from G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE010 신지윤\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11184999  =      0.000 ... 22369.998 secs...
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'LOC', 'ROC'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Scaling factor is not defined in following channels:
# ...

# %%
df_accuracy = each_subject.by_eeg_eog(i)
i += 1
df_accuracy
# Out:
# ['LE004 박규희', 'LE010 신지윤', 'LE011 서영진', 'LE014 황지은', 'LE019 황주민', 'LE020 김세영', 'LE021 이지영', 'LE023 이해림']
#
# -- Number of prepared subjects: 8
# Now edf: G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE011 서영진\Traces.edf
# Extracting EDF parameters from G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE011 서영진\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 11113999  =      0.000 ... 22227.998 secs...
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'LOC', 'SO', 'ROC'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Scaling factor is not defined in following channels:
# ...

# %%
df_accuracy = each_subject.by_eeg_eog(i)
i += 1
df_accuracy
# Out:
# ['LE004 박규희', 'LE010 신지윤', 'LE011 서영진', 'LE014 황지은', 'LE019 황주민', 'LE020 김세영', 'LE021 이지영', 'LE023 이해림']
#
# -- Number of prepared subjects: 8
# Now edf: G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE014 황지은\Traces.edf
# Extracting EDF parameters from G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE014 황지은\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10512499  =      0.000 ... 21024.998 secs...
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'L-Leg', 'R-Leg', 'Chin', 'LOC', 'SO', 'ROC'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Scaling factor is not defined in following channels:
# ...

# %%
df_accuracy = each_subject.by_eeg_eog(i)
i += 1
df_accuracy
# Out:
# ['LE004 박규희', 'LE010 신지윤', 'LE011 서영진', 'LE014 황지은', 'LE019 황주민', 'LE020 김세영', 'LE021 이지영', 'LE023 이해림']
#
# -- Number of prepared subjects: 8
# Now edf: G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE019 황주민\Traces.edf
# Extracting EDF parameters from G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE019 황주민\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10938999  =      0.000 ... 21877.998 secs...
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'LOC', 'ROC'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Scaling factor is not defined in following channels:
# ...

# %%
df_accuracy = each_subject.by_eeg_eog(i)
i += 1
df_accuracy
# Out:
# ['LE004 박규희', 'LE010 신지윤', 'LE011 서영진', 'LE014 황지은', 'LE019 황주민', 'LE020 김세영', 'LE021 이지영', 'LE023 이해림']
#
# -- Number of prepared subjects: 8
# Now edf: G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE020 김세영\Traces.edf
# Extracting EDF parameters from G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE020 김세영\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10490999  =      0.000 ... 20981.998 secs...
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'LOC', 'SO', 'ROC'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Scaling factor is not defined in following channels:
# ...

# %%
df_accuracy = each_subject.by_eeg_eog(i)
i += 1
df_accuracy
# Out:
# ['LE004 박규희', 'LE010 신지윤', 'LE011 서영진', 'LE014 황지은', 'LE019 황주민', 'LE020 김세영', 'LE021 이지영', 'LE023 이해림']
#
# -- Number of prepared subjects: 8
# Now edf: G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE021 이지영\Traces.edf
# Extracting EDF parameters from G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE021 이지영\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10325999  =      0.000 ... 20651.998 secs...
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'LOC', 'ROC'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Scaling factor is not defined in following channels:
# ...

# %%
df_accuracy = each_subject.by_eeg_eog(i)
i += 1
df_accuracy
# Out:
# ['LE004 박규희', 'LE010 신지윤', 'LE011 서영진', 'LE014 황지은', 'LE019 황주민', 'LE020 김세영', 'LE021 이지영', 'LE023 이해림']
#
# -- Number of prepared subjects: 8
# Now edf: G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE023 이해림\Traces.edf
# Extracting EDF parameters from G:\다른 컴퓨터\내 노트북\USC\Sleep dataset\Samsung_data\REGULAR_EDF\LE023 이해림\Traces.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10552999  =      0.000 ... 21105.998 secs...
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'LOC', 'SO', 'ROC'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(now_edf, preload=True)
# G:\다른 컴퓨터\내 노트북\USC\code_mine\yasa_examination\each_subject.py:31: RuntimeWarning: Scaling factor is not defined in following channels:
# ...
