# %% [markdown]
# # EDF file을 이용하여, YASA 모델을 이용하여 hypnogram을 predict하고 csv로 저장

# %% [markdown]
# # 1. LE dataset

# %%
import os
import pandas as pd
import staging_yasa
from tqdm.notebook import tqdm

path_subjects_edf = 'D:\\USC\\Sleep dataset\\Samsung_data\\NEW_EDF_matched'
subjects_edf = os.listdir(path_subjects_edf)
subjects_edf.sort()
print(subjects_edf)

# meas_time_df = pd.read_csv('D:\\USC\\code_mine\\Exploration_for_VD_dataset\\meas_time_edf_hypno.csv', index_col=0)
# meas_time_df = meas_time_df.loc['LE004':'LE023']
# meas_time_df
# Out:
# ['LE004.edf', 'LE010.edf', 'LE011.edf', 'LE014.edf', 'LE019.edf', 'LE020.edf', 'LE021.edf', 'LE023.edf']

# %% [markdown]
# # Without Filtering

# %%
filt_flag = 0
for subject_edf in tqdm(subjects_edf, desc='Total Progress'):
    print('\n==================================================')
    staging_yasa.get_yasa_hypnogram(path_subjects_edf, subject_edf, filt_flag)

# %% [markdown]
# # With Filtering

# %%
filt_flag = 1
for subject_edf in tqdm(subjects_edf, desc='Total Progress'):
    print('\n==================================================')
    staging_yasa.get_yasa_hypnogram(path_subjects_edf, subject_edf, filt_flag)
# Out:
# Total Progress:   0%|          | 0/8 [00:00<?, ?it/s]
# ...
# -- D:\USC\Sleep dataset\Samsung_data\NEW_EDF_matched\LE004.edf
# []
# Available channels: ['SO', 'C3', 'C4', 'IO']
# Down-sampling done ... 500.0Hz --> 100.0Hz
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 47.50 Hz)
# - Filter length: 1101 samples (11.010 sec)
#
# Filtering done; Bandpass Filter [0.3 45]...
# -- save done
#
# ...
# -- D:\USC\Sleep dataset\Samsung_data\NEW_EDF_matched\LE010.edf
# []
# Available channels: ['SO', 'C3', 'C4', 'IO']
# ...

# %% [markdown]
# # 2. VD dataset

# %%
import os
import pandas as pd
from tqdm.notebook import tqdm
import staging_yasa

path_subjects_edf = 'D:\\USC\\Sleep dataset\\Samsung_2nd\\VD_edf_matched'
subjects_edf = os.listdir(path_subjects_edf)
subjects_edf.sort()
print(subjects_edf)

# meas_time_df = pd.read_csv('D:\\USC\\code_mine\\Exploration_for_VD_dataset\\meas_time_edf_hypno.csv', index_col=0)
# meas_time_df
# Out:
# ['VD001.edf', 'VD002.edf', 'VD003.edf', 'VD004.edf', 'VD005.edf', 'VD006.edf', 'VD008.edf', 'VD011.edf', 'VD012.edf', 'VD017.edf', 'VD019.edf', 'VD022.edf', 'VD023.edf', 'VD025.edf', 'VD028.edf', 'VD029.edf', 'VD030.edf', 'VD031.edf', 'VD033.edf', 'VD034.edf', 'VD039.edf', 'VD041.edf', 'VD042.edf', 'VD043.edf', 'VD044.edf', 'VD045.edf', 'VD046.edf', 'VD047.edf', 'VD049.edf', 'VD050.edf', 'VD051.edf', 'VD052.edf', 'VD053.edf', 'VD054.edf', 'VD055.edf', 'VD056.edf', 'VD057.edf', 'VD058.edf']

# %% [markdown]
# # Without filtering

# %%
filt_flag = 0 
for subject_edf in tqdm(subjects_edf, desc='VD dataset Automatic Staging'):
    print('\n==================================================')
    staging_yasa.get_yasa_hypnogram(path_subjects_edf, subject_edf, filt_flag)
# Out:
# VD dataset Automatic Staging:   0%|          | 0/38 [00:00<?, ?it/s]
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD001.edf
# []
# Available channels: ['SO', 'C3', 'C4', 'O1', 'O2', 'IO', 'F3', 'F4']
# -- save done
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD002.edf
# []
# Available channels: ['SO', 'C3', 'C4', 'O1', 'O2', 'IO', 'F3', 'F4']
# -- save done
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD003.edf
# []
# Available channels: ['SO', 'C3', 'C4', 'O1', 'O2', 'IO', 'F3', 'F4']
# -- save done
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD004.edf
# []
# Available channels: ['SO', 'C3', 'C4', 'O1', 'O2', 'IO', 'F3', 'F4']
# -- save done
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD005.edf
# []
# Available channels: ['SO', 'C3', 'C4', 'O1', 'O2', 'IO', 'F3', 'F4']
# -- save done
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD006.edf
# []
# Available channels: ['SO', 'C3', 'C4', 'O1', 'O2', 'IO', 'F3', 'F4']
# ...

# %% [markdown]
# # With filtering

# %%
filt_flag = 1
for subject_edf in tqdm(subjects_edf, desc='VD dataset Automatic Staging'):
    print('\n==================================================')
    staging_yasa.get_yasa_hypnogram(path_subjects_edf, subject_edf, filt_flag)
# Out:
# VD dataset Automatic Staging:   0%|          | 0/38 [00:00<?, ?it/s]
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD001.edf
# []
# Available channels: ['SO', 'C3', 'C4', 'O1', 'O2', 'IO', 'F3', 'F4']
# Down-sampling done ... 500.0Hz --> 100.0Hz
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 47.50 Hz)
# - Filter length: 1101 samples (11.010 sec)
#
# Filtering done; Bandpass Filter [0.3 45]...
# -- save done
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD002.edf
# []
# ...

# %% [markdown]
# # 아래 코드는 filt 적용 이전에 사용한 코드

# %%
import os
import pandas as pd
import staging_yasa

path_subjects_edf = 'D:\\USC\\Sleep dataset\\Samsung_2nd\\VD_edf_matched'
subjects_edf = os.listdir(path_subjects_edf)
subjects_edf.sort()
print(subjects_edf)

# meas_time_df = pd.read_csv('D:\\USC\\code_mine\\Exploration_for_VD_dataset\\meas_time_edf_hypno.csv', index_col=0)
# meas_time_df
# Out:
# ['VD001.edf', 'VD002.edf', 'VD003.edf', 'VD004.edf', 'VD005.edf', 'VD006.edf', 'VD008.edf', 'VD011.edf', 'VD012.edf', 'VD017.edf', 'VD019.edf', 'VD022.edf', 'VD023.edf', 'VD025.edf', 'VD028.edf', 'VD029.edf', 'VD030.edf', 'VD031.edf', 'VD033.edf', 'VD034.edf', 'VD039.edf', 'VD041.edf', 'VD042.edf', 'VD043.edf', 'VD044.edf', 'VD045.edf', 'VD046.edf', 'VD047.edf', 'VD049.edf', 'VD050.edf', 'VD051.edf', 'VD052.edf', 'VD053.edf', 'VD054.edf', 'VD055.edf', 'VD056.edf', 'VD057.edf', 'VD058.edf']

# %%
for subject_edf in subjects_edf:
    print('\n==================================================')
    staging_yasa.get_yasa_hypnogram(path_subjects_edf, subject_edf, meas_time_df)
# Out:
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD001.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD002.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD003.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD004.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD005.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD006.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD008.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD011.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD012.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD017.edf
# []
# ---- save done
#
#
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched\VD019.edf
# []
# ---- save done
#
#
# ...
