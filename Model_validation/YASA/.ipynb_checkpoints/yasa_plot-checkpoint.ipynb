# %% [markdown]
# # YASA acc 결과를 기반으로, 선택적으로  hypnogram plot

# %%
import os
import yasa
import pandas as pd
import get_acc_matrix
import matplotlib.pyplot as plt

# %%
path_subejcts_g_hpyno = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\ground_truth' 
subjects_g_hypno = os.listdir(path_subejcts_g_hpyno)
subjects_g_hypno.sort()
print(subjects_g_hypno)

path_subejcts_p_hpyno = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\predicted' 
subjects_p_hypno = os.listdir(path_subejcts_p_hpyno)
subjects_p_hypno.sort()
print(subjects_p_hypno)
# Out:
# ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv', 'LE023.csv']
# ['LE004', 'LE010', 'LE011', 'LE014', 'LE019', 'LE020', 'LE021', 'LE023']

# %%
sub_num = 0

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_1 = []
#for csv_p_hypno in csv_p_hypnos:
csv_p_hypno = csv_p_hypnos[3]
path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
p_hypno_1 = pd.read_csv(path_p_hypno).squeeze()

csv_p_hypno = csv_p_hypnos[4]
path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
p_hypno_2 = pd.read_csv(path_p_hypno).squeeze()

yasa.plot_hypnogram(g_hypno)
plt.title('Ground_truth', fontsize=30)

yasa.plot_hypnogram(p_hypno_1)
plt.title('No_EOG_C4', fontsize=30)

yasa.plot_hypnogram(p_hypno_2)
plt.title('SO_C3', fontsize=30)
# Out:
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE004.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# Text(0.5, 1.0, 'SO_C3')

# %%
sub_num = 3

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_1 = []
#for csv_p_hypno in csv_p_hypnos:
csv_p_hypno = csv_p_hypnos[1]
path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
p_hypno_1 = pd.read_csv(path_p_hypno).squeeze()

csv_p_hypno = csv_p_hypnos[2]
path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
p_hypno_2 = pd.read_csv(path_p_hypno).squeeze()

yasa.plot_hypnogram(g_hypno)
plt.title('Ground_truth', fontsize=30)

yasa.plot_hypnogram(p_hypno_1)
plt.title('IO_C4', fontsize=30)

yasa.plot_hypnogram(p_hypno_2)
plt.title('No_EOG_C3', fontsize=30)
# Out:
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE014.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# Text(0.5, 1.0, 'No_EOG_C3')

# %%
sub_num = 7

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_1 = []
#for csv_p_hypno in csv_p_hypnos:
csv_p_hypno = csv_p_hypnos[1]
path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
p_hypno_1 = pd.read_csv(path_p_hypno).squeeze()

csv_p_hypno = csv_p_hypnos[3]
path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
p_hypno_2 = pd.read_csv(path_p_hypno).squeeze()

yasa.plot_hypnogram(g_hypno)
plt.title('Ground_truth', fontsize=30)

yasa.plot_hypnogram(p_hypno_1)
plt.title('IO_C4', fontsize=30)

yasa.plot_hypnogram(p_hypno_2)
plt.title('No_EOG_C4', fontsize=30)
# Out:
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE023.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# Text(0.5, 1.0, 'No_EOG_C4')
