# %%
import os
import yasa
import pandas as pd
import seaborn as sns

# %%
now_sub = 'PE190925'

# %%
path_g_hpyno = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\ground_truth'
path_g_now_sub = os.path.join(path_g_hpyno, now_sub+'.csv')
g_hypno = pd.read_csv(path_g_now_sub).squeeze()
yasa.plot_hypnogram(g_hypno)

path_p_hypno = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\pred_filt_reref'
path_p_now_sub = os.path.join(path_p_hypno, now_sub, 'pred_hypno', 'pred_hypno_C4.csv')
p_hypno = pd.read_csv(path_p_now_sub).squeeze()
yasa.plot_hypnogram(p_hypno)
# Out:
# <AxesSubplot:xlabel='Time [hrs]', ylabel='Stage'>

# %%
path_prob = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\pred_filt_reref'
path_prob_now_sub = os.path.join(path_prob, now_sub, 'prob', 'C4_prob.csv')
prob = pd.read_csv(path_prob_now_sub, index_col=0)
sns.heatmap(prob.transpose())
# Out:
# <AxesSubplot:xlabel='epoch'>
