# %% [markdown]
# # yasa 기반으로 구한 hypnogram을 ground_truth와 비교하여 accuracy 계산

# %% [markdown]
# # For LE dataset

# %%
import os
import yasa
import pandas as pd
import get_acc_matrix

# %% [markdown]
# # without filtering

# %%
path_subejcts_g_hpyno = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\ground_truth' 
subjects_g_hypno = os.listdir(path_subejcts_g_hpyno)
subjects_g_hypno.sort()
subjects_g_hypno = subjects_g_hypno[0:7]
print("[Ground-truth]")
print("   -- path of ground_truth: {}".format(path_subejcts_g_hpyno))
print("   -- csv files: {}".format(subjects_g_hypno))

path_subejcts_p_hpyno = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\predicted_without_filt' 
subjects_p_hypno = os.listdir(path_subejcts_p_hpyno)
subjects_p_hypno.sort()
subjects_p_hypno = subjects_p_hypno[0:7]
print("\n[Predicted]")
print("   -- path of predicted: {}".format(path_subejcts_p_hpyno))
print("   -- folders for the each subject: {}".format(subjects_p_hypno))
# Out:
# [Ground-truth]
#    -- path of ground_truth: D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth
#    -- csv files: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv']
#
# [Predicted]
#    -- path of predicted: D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt
#    -- folders for the each subject: ['LE004', 'LE010', 'LE011', 'LE014', 'LE019', 'LE020', 'LE021']

# %%
dic_acc_total = {} # subect 별로 chan_comb에 따른 overall accuracy가 저장됨
dic_matrix_total = {} # subject 별로 6개의 matrix가 저장됨
key_total = [] # subject name이 key로써 저장됨
sub_num = 0

for subject in subjects_p_hypno:
    print('========================================')
    path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
    print(f"-- now ground_truth:\n   {path_g_hypno}")
    g_hypno = pd.read_csv(path_g_hypno).squeeze()

    csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], 'pred_hypno'))
    print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

    dic_acc_sub = {} # 한 명의 subject 내에서, 채널 조합 별 acc를 저장하는 dictionary
    dic_matrix_sub = {} # 한 명의 subject 내에서, 채널 조합 별 matrix를 저장하는 dictionary
    dic_acc_sub_key = ['IO_C3', 'IO_C4', 'no_eog_C3', 'no_eog_C4', 'SO_C3', 'SO_C4'] # dic_acc_sub에 접근하기 위한 key가 담긴 list
    ch_comb_num = 0
    
    for csv_p_hypno in csv_p_hypnos:
        path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], 'pred_hypno', csv_p_hypno)
        print(path_p_hypno)
        p_hypno = pd.read_csv(path_p_hypno).squeeze()

        # overall accuracy
        accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100 # 현재 channel combination에 대한 overall accuracy 계산
        dic_acc_sub[dic_acc_sub_key[ch_comb_num]] = accuracy # dictionary에 추가  

        # accuracy matrix
        matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
        dic_matrix_sub[dic_acc_sub_key[ch_comb_num]] = matrix 

        ch_comb_num += 1  

    key_total.append(subjects_p_hypno[sub_num])
    dic_acc_total[key_total[sub_num]] = dic_acc_sub
    dic_matrix_total[key_total[sub_num]] = dic_matrix_sub
    sub_num += 1
# Out:
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE004.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE004\pred_hypno\_IO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE004\pred_hypno\_IO_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE004\pred_hypno\_no_eog_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE004\pred_hypno\_no_eog_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE004\pred_hypno\_SO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE004\pred_hypno\_SO_C4.csv
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE010.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE010\pred_hypno\_IO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE010\pred_hypno\_IO_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE010\pred_hypno\_no_eog_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE010\pred_hypno\_no_eog_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE010\pred_hypno\_SO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE010\pred_hypno\_SO_C4.csv
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE011.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE011\pred_hypno\_IO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE011\pred_hypno\_IO_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE011\pred_hypno\_no_eog_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE011\pred_hypno\_no_eog_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE011\pred_hypno\_SO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE011\pred_hypno\_SO_C4.csv
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE014.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE014\pred_hypno\_IO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE014\pred_hypno\_IO_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE014\pred_hypno\_no_eog_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE014\pred_hypno\_no_eog_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE014\pred_hypno\_SO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE014\pred_hypno\_SO_C4.csv
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE019.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE019\pred_hypno\_IO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE019\pred_hypno\_IO_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE019\pred_hypno\_no_eog_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE019\pred_hypno\_no_eog_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE019\pred_hypno\_SO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE019\pred_hypno\_SO_C4.csv
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE020.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE020\pred_hypno\_IO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE020\pred_hypno\_IO_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE020\pred_hypno\_no_eog_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE020\pred_hypno\_no_eog_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE020\pred_hypno\_SO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE020\pred_hypno\_SO_C4.csv
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE021.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE021\pred_hypno\_IO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE021\pred_hypno\_IO_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE021\pred_hypno\_no_eog_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE021\pred_hypno\_no_eog_C4.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE021\pred_hypno\_SO_C3.csv
# D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_without_filt\LE021\pred_hypno\_SO_C4.csv

# %%
df_no_filt = pd.DataFrame(dic_acc_total)

# %% [markdown]
# # with filtering

# %%
path_subejcts_g_hpyno = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\ground_truth' 
subjects_g_hypno = os.listdir(path_subejcts_g_hpyno)
subjects_g_hypno.sort()
subjects_g_hypno = subjects_g_hypno[0:7]
print("[Ground-truth]")
print("   -- path of ground_truth: {}".format(path_subejcts_g_hpyno))
print("   -- csv files: {}".format(subjects_g_hypno))

path_subejcts_p_hpyno = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\predicted_with_filt' 
subjects_p_hypno = os.listdir(path_subejcts_p_hpyno)
subjects_p_hypno.sort()
subjects_p_hypno = subjects_p_hypno[0:7]
print("\n[Predicted]")
print("   -- path of predicted: {}".format(path_subejcts_p_hpyno))
print("   -- folders for the each subject: {}".format(subjects_p_hypno))
# Out:
# [Ground-truth]
#    -- path of ground_truth: D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth
#    -- csv files: ['LE004.csv', 'LE010.csv', 'LE011.csv', 'LE014.csv', 'LE019.csv', 'LE020.csv', 'LE021.csv']
#
# [Predicted]
#    -- path of predicted: D:\USC\code_mine\Model_validation\YASA\hypnograms\predicted_with_filt
#    -- folders for the each subject: ['LE004', 'LE010', 'LE011', 'LE014', 'LE019', 'LE020', 'LE021']

# %%
dic_acc_total = {} # subect 별로 chan_comb에 따른 overall accuracy가 저장됨
dic_matrix_total = {} # subject 별로 6개의 matrix가 저장됨
key_total = [] # subject name이 key로써 저장됨
sub_num = 0

for subject in subjects_p_hypno:
    print('========================================')
    path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
    print(f"-- now ground_truth:\n   {path_g_hypno}")
    g_hypno = pd.read_csv(path_g_hypno).squeeze()

    csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], 'pred_hypno'))
    print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

    dic_acc_sub = {} # 한 명의 subject 내에서, 채널 조합 별 acc를 저장하는 dictionary
    dic_matrix_sub = {} # 한 명의 subject 내에서, 채널 조합 별 matrix를 저장하는 dictionary
    dic_acc_sub_key = ['IO_C3', 'IO_C4', 'no_eog_C3', 'no_eog_C4', 'SO_C3', 'SO_C4'] # dic_acc_sub에 접근하기 위한 key가 담긴 list
    ch_comb_num = 0
    
    for csv_p_hypno in csv_p_hypnos:
        path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], 'pred_hypno', csv_p_hypno)
#         print(path_p_hypno)
        p_hypno = pd.read_csv(path_p_hypno).squeeze()

        # overall accuracy
        accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100 # 현재 channel combination에 대한 overall accuracy 계산
        dic_acc_sub[dic_acc_sub_key[ch_comb_num]] = accuracy # dictionary에 추가  

        # accuracy matrix
        matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
        dic_matrix_sub[dic_acc_sub_key[ch_comb_num]] = matrix 

        ch_comb_num += 1  

    key_total.append(subjects_p_hypno[sub_num])
    dic_acc_total[key_total[sub_num]] = dic_acc_sub
    dic_matrix_total[key_total[sub_num]] = dic_matrix_sub
    sub_num += 1
# Out:
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE004.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE010.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE011.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE014.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE019.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE020.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']
# ========================================
# -- now ground_truth:
#    D:\USC\code_mine\Model_validation\YASA\hypnograms\ground_truth\LE021.csv
#
# -- pridicted hypnograms: ['_IO_C3.csv', '_IO_C4.csv', '_no_eog_C3.csv', '_no_eog_C4.csv', '_SO_C3.csv', '_SO_C4.csv']

# %%
df_filt = pd.DataFrame(dic_acc_total)

# %%
df_filt
# Out:
#                LE004      LE010      LE011      LE014      LE019      LE020  \
# IO_C3      43.234837  78.255034  76.972833  80.232558  73.198847  73.925501
# IO_C4      42.612753  79.865772  75.808538  80.523256  73.919308  73.925501
# no_eog_C3  41.679627  75.167785  74.773609  76.308140  75.072046  76.504298
# no_eog_C4  38.880249  77.583893  73.350582  78.052326  71.902017  77.220630
# SO_C3      44.479005  75.973154  73.609314  77.761628  73.631124  78.366762
# SO_C4      41.835148  77.046980  73.738680  79.069767  71.613833  78.653295
#
#                LE021
# IO_C3      73.313343
# IO_C4      73.463268
# no_eog_C3  72.113943
# no_eog_C4  77.211394
# SO_C3      75.262369
# SO_C4      78.410795

# %%
df_diff = df_no_filt - df_filt

# %%
df_diff.loc[:, 'SUM'] = df_diff.sum(axis=1)
df_diff.loc[:, 'mean'] = df_diff.loc[:,'LE004':'LE021'].mean(axis=1)
df_diff
# Out:
#               LE004     LE010     LE011     LE014     LE019     LE020  \
# IO_C3      0.000000  0.134228  0.000000 -0.581395  0.000000 -0.429799
# IO_C4     -0.155521 -0.268456 -0.129366  0.000000  0.144092 -0.286533
# no_eog_C3  1.088647  0.000000  0.129366 -0.290698  0.000000 -0.286533
# no_eog_C4  1.088647  0.000000  0.000000  0.581395  0.000000  0.286533
# SO_C3     -0.466563  0.000000 -0.129366 -0.290698  1.008646  0.429799
# SO_C4      0.000000 -0.536913 -0.517464 -0.145349  1.296830  0.000000
#
#               LE021       SUM      mean
# IO_C3      0.449775 -0.854383 -0.061027
# IO_C4      0.449775 -0.492018 -0.035144
# no_eog_C3  0.749625  2.780815  0.198630
# no_eog_C4  0.149925  4.213001  0.300929
# SO_C3      0.299850  1.703337  0.121667
# SO_C4     -0.449775 -0.705342 -0.050382

# %% [markdown]
# ## LE004

# %%
sub_num = 0

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_1 = []
for csv_p_hypno in csv_p_hypnos:
    path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
    p_hypno = pd.read_csv(path_p_hypno).squeeze()

    accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100
    total_acc_1.append(accuracy)
    matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
    print('==================================')
    print(matrix)

dic_acc = {
    'acc': total_acc_1
}

df_acc = pd.DataFrame(dic_acc, index=csv_p_hypnos)
df_acc
#     print('   -- {} --> %.2f %%'.format(csv_p_hypno[1:]) % accuracy)

# %% [markdown]
# # LE010

# %%
sub_num += 1

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_2 = []
for csv_p_hypno in csv_p_hypnos:
    path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
    p_hypno = pd.read_csv(path_p_hypno).squeeze()

    accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100
    total_acc_2.append(accuracy)
    matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
    print('==================================')
    print(matrix)

dic_acc = {
    'acc': total_acc_2
}

df_acc = pd.DataFrame(dic_acc, index=csv_p_hypnos)
df_acc
#     print('   -- {} --> %.2f %%'.format(csv_p_hypno[1:]) % accuracy)

# %% [markdown]
# # LE011

# %%
sub_num += 1

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_3 = []
for csv_p_hypno in csv_p_hypnos:
    path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
    p_hypno = pd.read_csv(path_p_hypno).squeeze()

    accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100
    total_acc_3.append(accuracy)
    matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
    print('==================================')
    print(matrix)

dic_acc = {
    'acc': total_acc_3
}

df_acc = pd.DataFrame(dic_acc, index=csv_p_hypnos)
df_acc
#     print('   -- {} --> %.2f %%'.format(csv_p_hypno[1:]) % accuracy)

# %% [markdown]
# # LE014

# %%
sub_num += 1

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_4 = []
for csv_p_hypno in csv_p_hypnos:
    path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
    p_hypno = pd.read_csv(path_p_hypno).squeeze()

    accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100
    total_acc_4.append(accuracy)
    matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
    print('==================================')
    print(matrix)

dic_acc = {
    'acc': total_acc_4
}

df_acc = pd.DataFrame(dic_acc, index=csv_p_hypnos)
df_acc
#     print('   -- {} --> %.2f %%'.format(csv_p_hypno[1:]) % accuracy)

# %% [markdown]
# # LE019

# %%
sub_num += 1

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_5 = []
for csv_p_hypno in csv_p_hypnos:
    path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
    p_hypno = pd.read_csv(path_p_hypno).squeeze()

    accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100
    total_acc_5.append(accuracy)
    matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
    print('==================================')
    print(matrix)

dic_acc = {
    'acc': total_acc_5
}

df_acc = pd.DataFrame(dic_acc, index=csv_p_hypnos)
df_acc
#     print('   -- {} --> %.2f %%'.format(csv_p_hypno[1:]) % accuracy)

# %% [markdown]
# # LE020

# %%
sub_num += 1

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_6 = []
for csv_p_hypno in csv_p_hypnos:
    path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
    p_hypno = pd.read_csv(path_p_hypno).squeeze()

    accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100
    total_acc_6.append(accuracy)
    matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
    print('==================================')
    print(matrix)

dic_acc = {
    'acc': total_acc_6
}

df_acc = pd.DataFrame(dic_acc, index=csv_p_hypnos)
df_acc
#     print('   -- {} --> %.2f %%'.format(csv_p_hypno[1:]) % accuracy)

# %% [markdown]
# # LE021

# %%
sub_num += 1

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_7 = []
for csv_p_hypno in csv_p_hypnos:
    path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
    p_hypno = pd.read_csv(path_p_hypno).squeeze()

    accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100
    total_acc_7.append(accuracy)
    matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
    print('==================================')
    print(matrix)

dic_acc = {
    'acc': total_acc_7
}

df_acc = pd.DataFrame(dic_acc, index=csv_p_hypnos)
df_acc
#     print('   -- {} --> %.2f %%'.format(csv_p_hypno[1:]) % accuracy)

# %% [markdown]
# # LE023

# %%
sub_num += 1

path_g_hypno = os.path.join(path_subejcts_g_hpyno, subjects_g_hypno[sub_num])
print(f"-- now ground_truth:\n   {path_g_hypno}")
g_hypno = pd.read_csv(path_g_hypno).squeeze()

csv_p_hypnos = os.listdir(os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num]))
print(f"\n-- pridicted hypnograms: {csv_p_hypnos}")

total_acc_8 = []
for csv_p_hypno in csv_p_hypnos:
    path_p_hypno = os.path.join(path_subejcts_p_hpyno, subjects_p_hypno[sub_num], csv_p_hypno)
    p_hypno = pd.read_csv(path_p_hypno).squeeze()

    accuracy = (g_hypno == p_hypno).sum() / p_hypno.size * 100
    total_acc_8.append(accuracy)
    matrix = get_acc_matrix.get_acc_matrix(g_hypno, p_hypno)
    print('==================================')
    print(matrix)

dic_acc = {
    'acc': total_acc_8
}

df_acc = pd.DataFrame(dic_acc, index=csv_p_hypnos)
df_acc
#     print('   -- {} --> %.2f %%'.format(csv_p_hypno[1:]) % accuracy)

# %%
subjects_p_hypno

# %%
dic_total_acc = {
    subjects_p_hypno[0]: total_acc_1,
    subjects_p_hypno[1]: total_acc_2,
    subjects_p_hypno[2]: total_acc_3,
    subjects_p_hypno[3]: total_acc_4,
    subjects_p_hypno[4]: total_acc_5,
    subjects_p_hypno[5]: total_acc_6,
    subjects_p_hypno[6]: total_acc_7,
    subjects_p_hypno[7]: total_acc_8    
}

df_total_acc = pd.DataFrame(dic_total_acc, index=csv_p_hypnos)
df_total_acc

# %%
transition 일 때 확률의 변화 모양
hypnogram
둘다 고려해야 한다
