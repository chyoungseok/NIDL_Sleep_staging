# %% [markdown]
# # LE dataset

# %%
import os
import pandas as pd
import staging_yasa
from tqdm.notebook import tqdm

# %%
path_subjects_edf = 'D:\\USC\\Sleep dataset\\Samsung_data\\NEW_EDF_matched_rereferenced'
subjects_edf = os.listdir(path_subjects_edf)
subjects_edf.sort()
print(subjects_edf)
# Out:
# ['LE004.edf', 'LE010.edf', 'LE011.edf', 'LE014.edf', 'LE019.edf', 'LE020.edf', 'LE021.edf', 'LE023.edf']

# %%
filt_flag = 1
path_save = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\pred_filt_reref'
for subject_edf in tqdm(subjects_edf, desc='Total Progress'):
    print('\n==================================================')
    staging_yasa.get_yasa_hypnogram(path_subjects_edf, subject_edf, filt_flag, path_save)
# Out:
# Total Progress:   0%|          | 0/8 [00:00<?, ?it/s]
# ...
# -- D:\USC\Sleep dataset\Samsung_data\NEW_EDF_matched_rereferenced\LE004.edf
# []
# Available channels: ['SO', 'A1', 'C3', 'C4', 'A2', 'O1', 'O2', 'IO', 'F3', 'F4']
# Down-sampling done ... 500.0Hz --> 100.0Hz
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 47.50 Hz)
# - Filter length: 1101 samples (11.010 sec)
#
# Filtering done; Bandpass Filter [0.3 45]...
# -- save done
#
# ...
# -- D:\USC\Sleep dataset\Samsung_data\NEW_EDF_matched_rereferenced\LE010.edf
# ...

# %% [markdown]
# # VD dataset

# %%
import os
import pandas as pd
import staging_yasa
from tqdm.notebook import tqdm

# %%
path_subjects_edf = 'D:\\USC\\Sleep dataset\\Samsung_2nd\\VD_edf_matched_rereferencing'
subjects_edf = os.listdir(path_subjects_edf)
subjects_edf.sort()
print(subjects_edf)
# Out:
# ['VD001.ed.edf', 'VD002.ed.edf', 'VD003.ed.edf', 'VD004.ed.edf', 'VD005.ed.edf', 'VD006.ed.edf', 'VD008.ed.edf', 'VD011.ed.edf', 'VD012.ed.edf', 'VD017.ed.edf', 'VD019.ed.edf', 'VD022.ed.edf', 'VD023.ed.edf', 'VD025.ed.edf', 'VD028.ed.edf', 'VD029.ed.edf', 'VD030.ed.edf', 'VD031.ed.edf', 'VD033.ed.edf', 'VD034.ed.edf', 'VD039.ed.edf', 'VD041.ed.edf', 'VD042.ed.edf', 'VD043.ed.edf', 'VD044.ed.edf', 'VD045.ed.edf', 'VD046.ed.edf', 'VD047.ed.edf', 'VD049.ed.edf', 'VD050.ed.edf', 'VD051.ed.edf', 'VD052.ed.edf', 'VD053.ed.edf', 'VD054.ed.edf', 'VD055.ed.edf', 'VD056.ed.edf', 'VD057.ed.edf', 'VD058.ed.edf']

# %%
filt_flag = 1
path_save = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\pred_filt_reref'
for subject_edf in tqdm(subjects_edf, desc='Total Progress'):
    print('\n==================================================')
    staging_yasa.get_yasa_hypnogram(path_subjects_edf, subject_edf, filt_flag, path_save)
# Out:
# Total Progress:   0%|          | 0/38 [00:00<?, ?it/s]
# ...
# -- D:\USC\Sleep dataset\Samsung_2nd\VD_edf_matched_rereferencing\VD001.ed.edf
# []
# Available channels: ['SO', 'A1', 'C3', 'C4', 'A2', 'O1', 'O2', 'IO', 'F3', 'F4']
# Down-sampling done ... 500.0Hz --> 100.0Hz
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 47.50 Hz)
# - Filter length: 1101 samples (11.010 sec)
#
# Filtering done; Bandpass Filter [0.3 45]...
# -- save done
#
# ...

# %% [markdown]
# # PE dataset

# %%
import os
import pandas as pd
import staging_yasa
from tqdm.notebook import tqdm

# %%
path_subjects_edf = 'D:\\USC\\Sleep dataset\\Samsung_3rd\\edf_matched_rereferenced'
subjects_edf = os.listdir(path_subjects_edf)
subjects_edf.sort()
print(subjects_edf)
# Out:
# ['PE150386.edf', 'PE180205.edf', 'PE180682.edf', 'PE180955.edf', 'PE181067.edf', 'PE190065.edf', 'PE190925.edf']

# %%
filt_flag = 1
path_save = 'D:\\USC\\code_mine\\Model_validation\\YASA\\hypnograms\\pred_filt_reref'
for subject_edf in tqdm(subjects_edf, desc='Total Progress'):
    print('\n==================================================')
    staging_yasa.get_yasa_hypnogram(path_subjects_edf, subject_edf, filt_flag, path_save)
# Out:
# Total Progress:   0%|          | 0/7 [00:00<?, ?it/s]
# ...
# -- D:\USC\Sleep dataset\Samsung_3rd\edf_matched_rereferenced\PE150386.edf
# []
# Available channels: ['SO', 'A2', 'C3', 'C4', 'O1', 'O2', 'IO', 'A1', 'F3', 'F4']
# Down-sampling done ... 200.0Hz --> 100.0Hz
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 47.50 Hz)
# - Filter length: 1101 samples (11.010 sec)
#
# Filtering done; Bandpass Filter [0.3 45]...
# -- save done
#
# ...
# -- D:\USC\Sleep dataset\Samsung_3rd\edf_matched_rereferenced\PE180205.edf
# ...
